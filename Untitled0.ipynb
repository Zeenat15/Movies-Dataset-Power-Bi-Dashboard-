# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('mymoviedb.csv')

# %%
data.head()
# Out:
#   Release_Date                    Title  \
# 0   15-12-2021  Spider-Man: No Way Home
# 1   01-03-2022               The Batman
# 2   25-02-2022                  No Exit
# 3   24-11-2021                  Encanto
# 4   22-12-2021           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...     5083.95       8940
# 1  In his second year of fighting crime, Batman u...     3827.66       1151
# 2  Stranded at a rest stop in the mountains durin...     2618.09        122
# 3  The tale of an extraordinary family, the Madri...     2402.20       5076
# 4  As a collection of history's worst tyrants and...     1895.51       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
data.isnull().sum()
# Out:
# Release_Date          0
# Title                 9
# Overview              9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# Poster_Url           11
# dtype: int64

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Release_Date         0
# Title                0
# Overview             0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Poster_Url           0
# dtype: int64

# %%
# List the column names
column_names = data.columns.tolist()
print(column_names)
# Out:
# ['Release_Date', 'Title', 'Overview', 'Popularity', 'Vote_Count', 'Vote_Average', 'Original_Language', 'Genre', 'Poster_Url']

# %%
# List of columns to drop
columns_to_drop = ['Overview', 'Poster_Url']  # Replace with the actual column names

# Drop the columns
data = data.drop(columns=columns_to_drop)
data.head()
# Out:
#   Release_Date                    Title  Popularity Vote_Count Vote_Average  \
# 0   15-12-2021  Spider-Man: No Way Home     5083.95       8940          8.3
# 1   01-03-2022               The Batman     3827.66       1151          8.1
# 2   25-02-2022                  No Exit     2618.09        122          6.3
# 3   24-11-2021                  Encanto     2402.20       5076          7.7
# 4   22-12-2021           The King's Man     1895.51       1793            7
#
#   Original_Language                               Genre
# 0                en  Action, Adventure, Science Fiction
# 1                en            Crime, Mystery, Thriller
# 2                en                            Thriller
# 3                en  Animation, Comedy, Family, Fantasy
# 4                en    Action, Adventure, Thriller, War

# %%
# Check the data type of the 'Popularity' column
print(data['Popularity'].dtype)

# Convert 'Popularity' to integer
data['Popularity'] = data['Popularity'].astype(int)
# Out:
# float64

# %%
data.head()
# Out:
#   Release_Date                    Title  Popularity Vote_Count Vote_Average  \
# 0   15-12-2021  Spider-Man: No Way Home        5083       8940          8.3
# 1   01-03-2022               The Batman        3827       1151          8.1
# 2   25-02-2022                  No Exit        2618        122          6.3
# 3   24-11-2021                  Encanto        2402       5076          7.7
# 4   22-12-2021           The King's Man        1895       1793            7
#
#   Original_Language                               Genre
# 0                en  Action, Adventure, Science Fiction
# 1                en            Crime, Mystery, Thriller
# 2                en                            Thriller
# 3                en  Animation, Comedy, Family, Fantasy
# 4                en    Action, Adventure, Thriller, War

# %%
import pandas as pd

# Assuming 'df' is your cleaned DataFrame
data.to_excel('cleaned_data.xlsx', index=False)
